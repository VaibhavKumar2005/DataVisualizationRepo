# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavKumar2005/DataVisualizationRepo/blob/main/DataVisualization3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
marks = [70, 60, 55, 68, 50]
subjects = ["Hindi", "English", " Science", "Maths", "GK"]
plt.pie(marks, labels = subjects, autopct = "%0.1f", explode = [0, 0.1, 0, 0, 0], shadow = True,
        colors = ["b", "g", "r", "violet", "gold"],
        startangle= 290,
        wedgeprops={"width" : .5},

        pctdistance = 0.8,
        textprops = {"color": "g", "fontweight" : "bold"})


plt.title("Marks")
plt.show()

# %%
tips = sns.load_dataset("tips")
tips
ddaywisetotalbill = tips.groupby("day")["total_bill"].sum().reset_index()
ddaywisetotalbill
# Out:
# /tmp/ipython-input-2901533413.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ddaywisetotalbill = tips.groupby("day")["total_bill"].sum().reset_index()
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
from matplotlib.patches import Circle

plt.pie(x = ddaywisetotalbill ["total_bill"],
        labels = ddaywisetotalbill["day"], autopct = "0.2f")
centre_circle = Circle((0,0), 0.40, fc = "white")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("Daywise Total Bill")
plt.show()

# %%
months = ["Jan", "Feb", "Apr", "May", "June"]
product_A = [100, 150, 200, 250, 300]
product_B = [80, 130, 150, 170, 220]

plt.plot(months, product_A, "d r")
